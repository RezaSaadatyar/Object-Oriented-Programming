# %%
class human:
    def __init__(self, name, lname, age):
        self.name = name 
        self.lname = lname
        self.age = age
    def fun(self):
        return f"{self.name}"

a = human(name="ali", lname="kf",age=20)
print(a.lname)
print(a.fun())
# Out:
# kf
# ali

# %%
class student:
    users = []
    users_course = {}
    
    def __init__(self, name, email, password, recive):
        self.name = name
        self.email = email
        self.password = password
        self.recive = recive
        # print(f"{self.name} wellcome!")
        student.users.append(self.name)
    
    def login(self, name):
        if name in student.users:
            print(f"{self.name} have an acount.")
        else:
            print(f"{self.name} must be register.")
            
    def buy(self, coursename):
        student.users_course[self.name] = coursename
        
output = student("aa","a@.com","2547", True)
output = student("rr","r@.com","247", True)
print(output.users)
output.login("t") 
# ali.login("bb")       

# print(ali.users_course)
# Out:
# ['aa', 'rr']
# rr must be register.
