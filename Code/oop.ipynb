# %% [markdown]
# **Concept of Object-oriented programming (OOP)**
# **Class:**
# - Class Variables
# - Constructor Method `__init__`
# - Methods
# - Inheritance
# - Overriding or Polymorphism
# - Abstraction
# - Endcapsulation

# %% [markdown]
# - Constructor Method `__init__`
#     - `__init__` is a special method in Python known as a constructor. It is automatically called when an instance of the class is created.<br/>
#     - `self` is a reference to the current instance of the class. It is used to access variables and methods that belong to the class.
# - Methods
#   - fun

# %%
class human:  # Define a class named `human`
    def __init__(self, name, lname, age):
        self.name = name  # Initialize `name` attribute with the provided first name
        self.lname = lname  # Initialize `lname` attribute with the provided last name
        self.age = age  # Initialize `age` attribute with the provided age value

    def fun(self):
        return f"{self.name}"  # Method that returns the first name of the human instance

# Create an object of the class `human` with specified attributes (name, lname, age)
a = human(name="ali", lname="kf", age=20)
# Access attributes
print(f"{a.age = }")  # Print the age of the object 'a' (age = 20)
print(f"{a.name = }")  # Print the name of the object 'a' (name = 'ali')
print(f"{a.lname = }")  # Print the last name of the object 'a' (lname = 'kf')

print(f"{a.fun() = }")  # Calls the 'fun' method of instance 'a' and prints the return value ("ali")
# Out:
# a.age = 20
# a.name = 'ali'
# a.lname = 'kf'
# a.fun() = 'ali'

# %% [markdown]
# - Class Variables
# - Constructor Method `__init__`
# - Methods
#   - login
#   - buy

# %%
class student:
    users = []                   # Class variable to store list of user names
    users_course = {}            # Class variable to store dictionary mapping user names to their courses
    
    def __init__(self, name, email, password, recive):
        self.name = name         # Instance variable to store the student's name
        self.email = email       # Instance variable to store the student's email
        self.password = password # Instance variable to store the student's password
        self.recive = recive     # Instance variable to store whether the student wants to receive updates
        # print(f"{self.name} wellcome!")  # Optional greeting print statement, currently commented out
        student.users.append(self.name)  # Adds the new student's name to the class variable list `users`
    
    def login(self, name):
        if name in student.users:  # Checks if the given name exists in the `users` list
            print(f"{name} have an acount.")  # Indicates the user has an account
        else:
            print(f"{name} must be register.")  # Indicates the user must register
            
    def buy(self, coursename): # Assigns the specified course to the student in `users_course` dictionary
        student.users_course[self.name] = coursename
        
output = student("aa", "a@.com", "2547", True)  # Creates an instance of `student` named "aa"
output.buy("matlab")  # The student "aa" purchases the "matlab" course
output = student("rr", "r@.com", "247", True)  # Creates another instance of `student` named "rr"
output.buy("python")  # The student "rr" purchases the "python" course
print(output.users)  # Prints the list of user names, expected output: ['aa', 'rr']
print(output.users_course)  # Prints the dictionary of users and their assigned courses
output.login("f")  # Attempts to log in a user named "f", expected print: "f must be register."
output = student("f", "f@.com", "5478", True)  # Creates a new instance of `student` named "f"
output.login("f")  # Now attempts to log in "f" again, expected print: "f have an acount."
print(output.users)  # Prints the updated list of user names, now including "f"
# Out:
# ['aa', 'rr']
# {'aa': 'matlab', 'rr': 'python'}
# f must be register.
# f have an acount.
# ['aa', 'rr', 'f']

# %% [markdown]
# - Class Variables
# - Constructor Method `__init__`
# - Methods
#   - remove
#   - login
#   - buy

# %%
class student:
    users = []                   
    users_course = {}            
    
    def __init__(self, name, email, password, receive):
        self.name = name         
        self.email = email       
        self.password = password 
        self.receive = receive   
        student.users.append(self.name)
        print(f"{self.name} is added.")
    
    # def __del__(self):
    #     student.users.remove(self.name)  # Attempt to remove user upon object deletion
    
    def remove_user(self):  # Explicit method to remove user
        student.users.remove(self.name)
        print(f"{self.name} is removed.")
        if self.name in student.users_course:
            del student.users_course[self.name]  # Also remove from users_course if exists
            print(f"course {self.name} is removed.")

    def login(self, name):
        if name in student.users:
            print(f"{name} has an account.")
        else:
            print(f"{name} must register.")
            
    def buy(self, coursename):
        student.users_course[self.name] = coursename
        print(f"{self.name} bought {coursename}.")

student_jame = student("Jame", "a@.com", "2547", True)  
student_jame.buy("matlab")
student_sara = student("Sara", "r@.com", "247", True)
student_sara.buy("python")
student_f = student("f", "f@.com", "5478", True)
student_f.login("f")
print(f"{student.users = }")
print(f"{student.users_course = }")

student_jame.remove_user()  # Call the new method to remove user
print(f"{student.users = }")
print(f"{student.users_course = }")
# Out:
# Jame is added.
# Jame bought matlab.
# Sara is added.
# Sara bought python.
# f is added.
# f has an account.
# student.users = ['Jame', 'Sara', 'f']
# student.users_course = {'Jame': 'matlab', 'Sara': 'python'}
# Jame is removed.
# course Jame is removed.
# student.users = ['Sara', 'f']
# student.users_course = {'Sara': 'python'}

# %% [markdown]
# - Constructor Method `__init__`
# - Representation Method `__repr__`
#   - `__repr__` is a special method used to define the string representation of an object. It returns a string that describes the object.

# %%
class human:
    def __init__(self, name, lname, age):
        self.name = name       # Instance variable for first name
        self.lname = lname     # Instance variable for last name
        self.age = age         # Instance variable for age
    
    def __repr__(self):
       return f"{self.name} {self.lname}: {self.age}"  # 

output = human(name="Sara", lname="kf", age=20)  # Creates an instance of human with specified attributes
print(output)  # Prints the last name of the instance 'a', which is "kf"
# Out:
# Sara kf: 20

# %% [markdown]
# **Inheritance**
# - Constructor Method `__init__`
# - Method
#   - sleep
# - Student Class (Inherits from person)
#   - The student class inherits from person, meaning it has access to the methods and properties of person, while also adding its own attributes and methods.
# - super().`__init__`
#   - The super() method is generally preferred for better maintainability and to support multiple inheritance.
# - Method
#   - score

# %%
class person:
    def __init__(self, name, lname, age):
        self.name = name
        self.lname = lname
        self.age = age
        
    def sleep(self):
        return f"{self.name} sleeping ...."

class student(person):
    def __init__(self, name, lname, age, student_id):
        person.__init__(self, name, lname, age)      # or super().__init__(name, lname, age)
        self.student_id = student_id
    
    def score(self):
        return f"{self.name} recived score."

output = student("Jame", "hfgddh", 25, 12547)
print(f"{output.student_id = }")
print(f"{output.sleep() = }")
print(f"{output.score() = }")
# Out:
# output.student_id = 12547
# output.sleep() = 'Jame sleeping ....'
# output.score() = 'Jame recived score.'

# %% [markdown]
# - *arg
#   - It allows a function to accept any number of positional arguments. The arguments passed with *args are stored in a tuple.
# - **kwarg
#   - It allows a function to accept any number of keyword arguments (arguments passed with a key-value pair). The arguments passed with **kwargs are stored in a dictionary.

# %%
def example(*args):
    for arg in args:
        print(arg)

example(1, 2, 3, 4, 5)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def example(**kwargs):
    for key, value in kwargs.items():
        print(f"{key}: {value}")

example(a=1, b=2, c=3)
# Out:
# a: 1
# b: 2
# c: 3

# %%
class person:
    def __init__(self, name, lname, age):
        self.name = name
        self.lname = lname
        self.age = age
        
    def sleep(self):
        return f"{self.name} sleeping ...."

class student(person):
    def __init__(self, student_id, *arg, **kwarg):
        person.__init__(self, *arg, **kwarg)      # or super().__init__(name, lname, age)
        self.student_id = student_id
    
    def score(self):
        return f"{self.name} recived score."

output = student(name="Jame", lname="hfgddh", age=25, student_id=12547)
print(f"{output.student_id = }")
print(f"{output.sleep() = }")
print(f"{output.score() = }")
# Out:
# output.student_id = 12547
# output.sleep() = 'Jame sleeping ....'
# output.score() = 'Jame recived score.'

# %% [markdown]
# **Polymorphism or Overloading**<br/>
# It allows a single interface (method or property) to be used for different underlying data types. In other words, it lets you call the same method on different objects, and each object can respond in its own way.

# %%
class parent:
    def fun(self):
        print("Parent class")

class child(parent):
    def fun(self):
        print("Child class")

p = parent()
c = child()
p.fun()
c.fun()
# Out:
# Parent class
# Child class

# %%
class Circle:
    def draw(self):
        print("Drawing a circle.")

class Square:
    def draw(self):
        print("Drawing a square.")
        
c = Circle()
s = Square()
c.draw()
s.draw()
# Out:
# Drawing a circle.
# Drawing a square.
